# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
from helper import *
data = getData("distA.csv")
stats.probplot(data, dist = 'norm', plot=plt)
plt.show() # modify this to write the plot to a file instead

# %% [markdown]
# As seen in the graph above, the red line illustrating the proper Gaussian graph most correcly matches the blue plots from the data set, indicating that it is a Gaussian graph

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
from helper import *
data = getData("distB.csv")
stats.probplot(data, dist = 'uniform', plot=plt)
plt.show() # modify this to write the plot to a file instead

# %% [markdown]
# As seen in the graph above, the red line illustrating the proper Uniform graph most correcly matches the blue plots from the data set, indicating that it is a Uniform graph

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
from helper import *
data = getData("distC.csv")
stats.probplot(data, dist = 'wald', plot=plt)
plt.show() # modify this to write the plot to a file instead

# %% [markdown]
# As seen in the graph above, the red line illustrating the proper Wald graph most correcly matches the blue plots in comparison to the other graph sets. There are a few outliers as the plot reaches higher values, however no other plot produces a result that yields an extremely low error, so the Wald plot is the best option for this data set
